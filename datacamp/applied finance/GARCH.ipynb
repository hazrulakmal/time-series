# %% [markdown]
# # GARCH
# #### forecasting changes in variance
#
# Generalized Autoregressive Conditional Heteroskedasticity
#
# ARCH
#
# white noise (z); uncorrelated random variables with a zero mean and a constant variance. (residuals) - things that a model cannot take care off due to its random propreties.
#
# Autoregressive ; predict future behaviour based on past behaviour

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

sp_data = pd.read_csv("data/SP500.csv", parse_dates=True, index_col='Date')
plt.plot(sp_data['Return'], color = 'tomato', label = 'Daily Returns')
plt.legend(loc='upper right')
plt.show()

# %%
# Calculate daily std of returns
std_daily = sp_data['Return'].std()
print('Daily volatility: ', '{:.2f}%'.format(std_daily))

# Convert daily volatility to monthly volatility
std_monthly = math.sqrt(21) * std_daily
print ('Monthly volatility: ', '{:.2f}%'.format(std_monthly))

# Convert daily volatility to annaul volatility
std_annual = math.sqrt(252) * std_daily
print ('Annual volatility: ', '{:.2f}%'.format(std_annual))
# Out:
# Daily volatility:  0.92%
# Monthly volatility:  4.20%
# Annual volatility:  14.54%
